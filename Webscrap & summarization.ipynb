# %% [markdown]
#  # Scraping a Wikipedia Webpage and Summarization

# %% [markdown]
# Step-01: Scraping the Wikipedia page (https://en.wikipedia.org/wiki/Alexander_the_Great) using beautiful soup by retaining the original headings and sub-headings.
#
# Step-02: Using the t5-base model for the summarization from the retrieved data from the scrapping.

# %% [markdown]
# ### Importing essential required libraries

# %%
import requests
from bs4 import BeautifulSoup
from transformers import pipeline

# %% [markdown]
# ### Function to fetch webpage content

# %%
def fetch_webpage(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.text
    else:
        raise Exception(f"Failed to fetch the webpage: Status code {response.status_code}")

# %% [markdown]
# ### Function to extract headings and text content using BeautifulSoup

# %%
def extract_headings_and_text(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    content = {}
    current_section = 'Introduction'  # Default section for content before first heading

    for element in soup.find_all(['h1', 'h2', 'h3', 'h4', 'p']):
        if element.name == 'h1':
            content['Title'] = element.get_text().strip()
        elif element.name in ['h2', 'h3', 'h4']:
            current_section = element.get_text().strip()
            content[current_section] = []
        elif element.name == 'p':
            if current_section not in content:
                content[current_section] = []
            content[current_section].append(element.get_text().strip())

    return content

# %% [markdown]
# ### Function to summarize content using transformers pipeline

# %%
def summarize_content(content):
    summarizer = pipeline("summarization", model="t5-base", device=0)  # Adjust 'device' as needed

    summarized_content = {}

    for section, texts in content.items():
        summarized_content[section] = []

        if isinstance(texts, list):
            for text in texts:
                summary = summarizer(text, max_length=150, min_length=30, do_sample=False)[0]['summary_text'].strip()
                summarized_content[section].append(summary)
        else:
            summary = summarizer(texts, max_length=150, min_length=30, do_sample=False)[0]['summary_text'].strip()
            summarized_content[section].append(summary)

    return summarized_content

# %% [markdown]
# ### Function call and printing the summarized content

# %%
def main():
    url = "https://en.wikipedia.org/wiki/Alexander_the_Great"
    webpage_content = fetch_webpage(url)
    content = extract_headings_and_text(webpage_content)
    summarized_content = summarize_content(content)

    for section, summaries in summarized_content.items():
        print(f"### {section}")
        if isinstance(summaries, list):
            for summary in summaries:
                print(summary)
        else:
            print(summaries)
        print()

if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Your max_length is set to 150, but your input_length is only 3. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=1)
# Your max_length is set to 150, but your input_length is only 136. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=68)
# Your max_length is set to 150, but your input_length is only 6. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# Your max_length is set to 150, but your input_length is only 139. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=69)
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Your max_length is set to 150, but your input_length is only 44. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 150, but your input_length is only 108. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 150, but your input_length is only 136. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=68)
# Your max_length is set to 150, but your input_length is only 139. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=69)
# Your max_length is set to 150, but your input_length is only 106. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Your max_length is set to 150, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 150, but your input_length is only 118. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=59)
# Your max_length is set to 150, but your input_length is only 142. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=71)
# Your max_length is set to 150, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 150, but your input_length is only 120. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)
# Your max_length is set to 150, but your input_length is only 55. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 150, but your input_length is only 138. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=69)
# Your max_length is set to 150, but your input_length is only 49. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 150, but your input_length is only 133. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=66)
# Your max_length is set to 150, but your input_length is only 148. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=74)
# Your max_length is set to 150, but your input_length is only 142. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=71)
# Your max_length is set to 150, but your input_length is only 116. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
# Your max_length is set to 150, but your input_length is only 49. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 150, but your input_length is only 43. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
# Your max_length is set to 150, but your input_length is only 135. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=67)
# Your max_length is set to 150, but your input_length is only 117. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
# Your max_length is set to 150, but your input_length is only 118. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=59)
# Your max_length is set to 150, but your input_length is only 137. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=68)
# Your max_length is set to 150, but your input_length is only 100. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 145. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=72)
# Your max_length is set to 150, but your input_length is only 132. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=66)
# Your max_length is set to 150, but your input_length is only 140. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=70)
# Your max_length is set to 150, but your input_length is only 129. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=64)
# Your max_length is set to 150, but your input_length is only 74. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 150, but your input_length is only 56. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Your max_length is set to 150, but your input_length is only 130. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=65)
# Your max_length is set to 150, but your input_length is only 117. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
# Your max_length is set to 150, but your input_length is only 121. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)
# Your max_length is set to 150, but your input_length is only 98. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 150, but your input_length is only 135. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=67)
# Your max_length is set to 150, but your input_length is only 142. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=71)
# Your max_length is set to 150, but your input_length is only 115. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=57)
# Your max_length is set to 150, but your input_length is only 43. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
# Your max_length is set to 150, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 150, but your input_length is only 134. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=67)
# Your max_length is set to 150, but your input_length is only 48. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 150, but your input_length is only 57. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Your max_length is set to 150, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 150, but your input_length is only 32. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
# Your max_length is set to 150, but your input_length is only 45. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 150, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 150, but your input_length is only 134. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=67)
# Your max_length is set to 150, but your input_length is only 149. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=74)
# Your max_length is set to 150, but your input_length is only 88. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
# Your max_length is set to 150, but your input_length is only 120. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Your max_length is set to 150, but your input_length is only 124. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
# Your max_length is set to 150, but your input_length is only 120. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=60)
# Your max_length is set to 150, but your input_length is only 125. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
# Your max_length is set to 150, but your input_length is only 143. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=71)
# Your max_length is set to 150, but your input_length is only 55. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 150, but your input_length is only 22. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=11)
# Your max_length is set to 150, but your input_length is only 67. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Your max_length is set to 150, but your input_length is only 131. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=65)
# Your max_length is set to 150, but your input_length is only 115. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=57)
# Your max_length is set to 150, but your input_length is only 53. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Your max_length is set to 150, but your input_length is only 118. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=59)
# Your max_length is set to 150, but your input_length is only 27. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
# Your max_length is set to 150, but your input_length is only 108. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 150, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 150, but your input_length is only 91. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=45)
# Your max_length is set to 150, but your input_length is only 133. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=66)
# Your max_length is set to 150, but your input_length is only 139. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=69)
# Your max_length is set to 150, but your input_length is only 78. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 150, but your input_length is only 104. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Your max_length is set to 150, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 150, but your input_length is only 25. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=12)
# Your max_length is set to 150, but your input_length is only 76. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 150, but your input_length is only 15. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
# Your max_length is set to 150, but your input_length is only 80. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 150, but your input_length is only 27. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=13)
# ### Contents
# . - (EL) - -________________________ -______________________ __________ __
# Alexander the Great was a king of the ancient Greek kingdom of Macedon . he succeeded his father Philip II to the throne in 336 BC . by the age of 30, he had created one of the largest empires in history .
# until the age of 16, Alexander was tutored by Aristotle . he campaigned in the balkans and reasserted control over Thrace and parts of Illyria . in 335 BC, he led the League of Corinth, assuming leadership over all Greeks .
# in 334 BC, he invaded the Achaemenid Persian Empire and began a series of campaigns . he overthrew Darius III and conquered the Macedonian Empire in its entirety . in the years following his death, civil wars broke out across the macedonian empire .
# his death marks the start of the Hellenistic period . he founded more than twenty cities, with the most prominent being the city of Alexandria . the Greek language became the lingua franca of the region .
# his military achievements and unprecedented enduring successes in battle made him the measure against which many later military leaders would compare themselves . his tactics remain a significant subject of study in military academies worldwide .
#
# ### Title
# Alexander the Great conquered the world in november . he was succeeded by the great king of syria in january .
#
# ### Early life
#
# ### Lineage and childhood
# Alexander III was born on the sixth day of the ancient Greek month of Hekatombaion . he was the son of the erstwhile king of Macedon, Philip II .
# legends surround Alexander's birth and childhood . Olympias dreamed that her womb was struck by a thunderbolt . ancient Greek biographer Plutarch offered a variety of interpretations .
# paul scholes: on day Alexander was born, Philip was preparing siege on city of Potidea . he says legends may have emerged to show that he was superhuman and destined for greatness . the temple of artemis in Ephesus, one of the seven wonders of the world, burned down .
# Alexander was raised by a nurse, Lanike, sister of his future general Cleitus the Black . he learned to read, play the lyre, ride, fight, and hunt . when his horse died, he named it Bucephalas, meaning "ox-head"
#
# ### Education
# when Alexander was 13, Philip began to search for a tutor . in return for teaching, he agreed to rebuild Aristotle's hometown of Stageira . he also agreed to free ex-citizens who were slaves, or pardon those in exile .
# mieza was like a boarding school for Alexander and the children of Macedonian nobles . under Aristotle's tutelage, Alexander developed a passion for the works of homer . he was able to quote Euripides from memory .
# in his youth, Alexander was also acquainted with Persian exiles at the Macedonian court . he may have influenced some of the innovations in the management of the macedonian state .
# Suda writes that Anaximenes of Lampsacus was one of Alexander's teachers . he also accompanied Alexander on his campaigns .
#
# ### Heir of Philip II
#
# ### Regency and ascent of Macedon
# the Thracian tribe of Maedi revolted against Macedonia . Alexander drove them from their territory, and a city, named Alexandropolis, was founded .
# while Philip was occupied in Thrace, Alexander mustered an army for a campaign in southern Greece . concerned that other Greek states might intervene, Alexander made it look as though he was preparing to attack Illyria instead .
# in 338 BC, Philip and his army marched south through Thermopylae . they went on to occupy the city of Elatea, only a few days' march from both Athens and Thebes . both athens, led by Demosthenes, voted to seek alliance with thebes against Macedonia .
# ancient sources say the two sides fought bitterly for some time . Philip deliberately commanded his troops to retreat, according to the ancient sources . with the Athenians lost, the Thebans were surrounded .
# a "hellenic alliance" was established at corinth, which included most Greek city-states except Sparta . "hegemon" was then named "Supreme Commander" of this league, known as the League of Corinth .
#
# ### Exile and return
# when Philip returned to Pella, he fell in love with and married Cleopatra Eurydice in 338 BC . the marriage made Alexander's position as heir less secure, since he was only half-Macedonian .
# at the wedding of Cleopatra, her uncle attalus in his drink desired the gods to give them a lawful successor to the kingdom by his niece . he so irritated his uncle that throwing one of the cups at his head, "you villain," said he, "what, am I then a bastard?"
# in 337 BC, Alexander fled Macedon with his mother, dropping her off with her brother . he continued to Illyria where he sought refuge with one or more kings . it appears Philip never intended to disown his politically and militarily trained son .
# in the following year, the Persian satrap offered his eldest daughter to Philip Arrhidaeus . when Philip heard of this, he scolded Alexander for wishing to marry the daughter of a Carian . he exiled four of Alexander's friends and had the Corinthians bring Thessalus to him in chains .
#
# ### King of Macedon
#
# ### Accession
# in the summer of 336 BC, Philip was assassinated by the captain of his bodyguards, Pausanias . he tripped over a vine and was killed by his pursuers, including two of Alexander's companions, perdiccas and Leonnatus .
#
# ### Consolidation of power
# he had two princes from the region of Lyncestis killed for being involved in his father's assassination . when Alexander learned about this, he was furious . he also ordered the murder of attalus, who was in command of the advance guard .
# attalus had severely insulted Alexander, and may have considered him too dangerous to be left alive . Arrhidaeus was by all accounts mentally disabled, possibly as a result of poisoning .
# when news of Philip's death roused many states into revolt, Alexander responded quickly . he mustered 3,000 Macedonian cavalry and rode south towards thessaly . when the Thessalians awoke the next day, they found Alexander in their rear .
# the famous encounter between Alexander and Diogenes the Cynic occurred during Alexander's stay in Corinth . Alexander took the title of Hegemon ("leader") and was appointed commander for the coming war against persia .
#
# ### Balkan campaign
# in the spring of 335 BC, Alexander advanced to suppress several revolts . he travelled east into the country of the "Independent Thracians" and defeated their army near the Lyginus river .
# king glaukias of the Taulantii and chieftain cleitus of the Illyrians were in open revolt . he defeated each in turn, forcing the two rulers to flee with their troops .
#
# ### Destruction of Thebes
# the end of Thebes cowed Athens, leaving all of Greece temporarily at peace . Alexander then set out on his Asian campaign, leaving Antipater as regent .
#
# ### Conquest of the Achaemenid Persian Empire
#
# ### Asia Minor
# in 336 he sent 10,000 men into Anatolia to prepare for an invasion . the Greek cities revolted until the news arrived that Philip had been murdered . Macedonians were demoralized by Philip's death and were defeated near Magnesia .
# in 334 BC, Alexander's army crossed the Hellespont with 48,100 soldiers, 6,100 cavalry . he said he accepted Asia as a gift from the gods .
# mercenary captain Memnon of Rhodes and the Persian satrap of Caria withdraw by sea . he waged his first large-scale siege at Halicarnassus, in Caria .
# cnn's john defterios reports that the future "king of Asia" "undid" the unsolvable Gordian Knot at the ancient Phrygian capital of Gordium . he hacked the knot apart with his sword, according to the story .
#
# ### The Levant and Syria
# in spring 333 BC, Alexander crossed the Taurus into Cilicia . he defeated Darius at Issus, where he left behind his wife, daughters and a fabulous treasure .
#
# ### Egypt
# when Alexander destroyed Tyre, most of the towns on the route to Egypt quickly capitulated . the stronghold was heavily fortified and built on a hill, requiring a siege . after three unsuccessful assaults, he received a serious shoulder wound .
# after his trip to Siwa, Alexander was crowned in the temple of Ptah at Memphis . it appears that the Egyptian people did not find it disturbing that he was a foreigner .
# Alexander made sacrifices to the gods at Memphis and went to consult the famous oracle of Amun-Ra at the Siwa Oasis in the Libyan desert . he was pronounced the son of the deity amun .
# he founded Alexandria, which would become the prosperous capital of the Ptolemaic Kingdom after his death . control of Egypt passed to ptolemy I (son of Lagos) after the death of Alexander .
#
# ### Assyria and Babylonia
# darius fled the field, and Alexander chased him as far as Arbela . Gaugamela would be the final and decisive encounter between the two .
# "the king of the world, Alexander" sent his scouts with a message to the people of Babylon . "i shall not enter your houses," he said .
#
# ### Persia
# he sent the bulk of his army to the Persian ceremonial capital of persepolis via the Persian Royal Road . he then stormed the pass of the Persian Gates which had been blocked by a Persian army .
# a fire broke out in the eastern palace of Xerxes I and spread to the rest of the city . Alexander began to regret his decision, but he did not regret it until the next morning . he stayed in persepolis for five months .
# shall I leave you lying there because of the expeditions you led against Greece? shall I set you up again because of your magnanimity and your virtues?
#
# ### Fall of the Persian Empire and the East
# the Achaemenid Empire is normally considered to have fallen with Darius . Alexander buried darius's remains next to his predecessors in a regal funeral .
# the campaign, initially against Bessus, turned into a grand tour of central Asia . Alexander founded a series of new cities, all called Alexandria, including modern Kandahar in Afghanistan .
# in 329 BC, Spitamenes betrayed bessus to one of Alexander's trusted companions . he raised sogdiana in revolt; Alexander defeated the Scythians at the battle of Jaxartes . after the defeat, he was killed by his own men, who then sued for peace .
#
# ### Problems and plots
# the custom of proskynesis was a symbolic kissing of the hand or prostration on the ground . the Greeks believed that Alexander meant to deify himself by requiring it . this cost him the sympathies of many of his countrymen .
# during the long rule of the Achaemenids, the elite positions in many segments of the empire were reserved for Iranians and to a major degree, Persian noblemen . Alexander realized that it was insufficient to merely exploit internal contradictions within the imperial system . he demonstrated awareness of this when he challenged incumbent King darius III .
# a plot against Alexander's life was revealed, and one of his officers was executed . infamously, he personally killed the man who saved his life at Granicus, Cleitus the Black .
# callisthenes of Olynthus was implicated in a second plot against his life . he and his royal pages were tortured on the rack as punishment, and likely died .
#
# ### Macedon in Alexander's absence
# sacking of thebes ensured that Greece remained quiet during his absence . antipater referred the Spartans' punishment to the League of Corinth, which then deferred to Alexander .
# in general, Greece enjoyed a period of peace and prosperity during Alexander's campaign in Asia . but the constant demands for troops and the migration of Macedonians depleted Macedon's strength . this led to its subjugation by Rome after the third Macedonian War (171–168 BC)
#
# ### Coinage
# the conquest by Philip II of Pangaeum and then of the island of Thasos brought rich gold and silver mines under Macedonian control .
# the gold series had the head of Athena on the obverse and a winged Nike (Victory) on the reverse . the silver coinage had a beardless head of Heracles wearing a lionskin headdress and Zeus aetophoros ('eagle bearer') enthroned .
# coinage continued to circulate in all the satrapies of the empire . Alexander did not attempt to impose uniform imperial coinage throughout his new conquests .
#
# ### Indian campaign
#
# ### Forays into the Indian subcontinent
# ambhi, a former satrapy of Gandhara, invited the chieftains of taxila to submit to his authority . he met with valuable presents and presented him with a wardrobe of persian robes . the gifts included 30 horses, 1,000 talents in gold and a bridge over the Indus .
# taxiles was entrusted with the government of the whole territory between the Hydaspes and the Indus . he was allowed to retain his authority at the death of Alexander himself (323 BC)
# in 327/326 BC, Alexander led a campaign against the Aspasioi of the Kunar Valley . he was wounded in the shoulder by a dart, but eventually the Assakenoi lost .
# the fort of Massaga was reduced after days of bloody fighting . numerous Assakenians fled to the fortress of Aornos . Alexander followed close behind and captured the strategic hill-fort .
# after Aornos, Alexander crossed the Indus and won an epic battle against King Porus . he appointed Porus as satrap and added to his territory land that he did not previously own . Alexander founded two cities on opposite sides of the Hydaspes river .
#
# ### Revolt of the Hellenic army
# east of Porus's kingdom, near the Ganges River, was the Nanda Empire of Magadha . further east, the Gangaridai Empire of Bengal region of the Indian subcontinent . fearing the prospect of facing other large armies, Alexander's army refused to march farther east .
# the macedonians fought an enemy who mustered only infantry and horse . they opposed Alexander when he insisted on crossing the river Ganges . kings of the Ganderites and Praesii were awaiting them with eighty thousand horsemen .
# an arrow penetrated his armor and entered his lung . his army conquered the Malhi and other Indian tribes . he suffered a near-fatal injury while marching along the Indus .
# he sent much of his army to carmania (modern southern Iran) with general Craterus . he led the rest back to persia through the more difficult southern route along the gedrosian desert .
#
# ### Last years in Persia
# many of his satraps and military governors had misbehaved in his absence . as a gesture of thanks, he paid off the debts of his soldiers . he announced that he would send over-aged and disabled veterans back to Macedon .
# edward mccaffery: unable to persuade his men to back down, he gave Persians command posts . he says he held a mass marriage of his senior officers to Persian and other noblewomen . but few of those marriages seem to have lasted much beyond a year .
# the tomb of Cyrus the Great in Pasargadae had been desecrated . he ordered his architect to decorate the interior of the sepulchral chamber of his tomb .
# his closest friend, Hephaestion, died of illness or poisoning . he ordered the preparation of an expensive funeral pyre in Babylon .
# the banquet was to celebrate the end of the campaign of India and the onset of the invasion of the Arabian Peninsula . tradition is that they would only start serious drinking after everyone was done with their meals .
#
# ### Death and succession
# he may have also added that there would be funeral games to be played after his death . "to the strongest one," he said before his death, if asked .
# there are two different versions of Alexander's death, differing slightly in details . Plutarch's account is that roughly 14 days before his death, Alexander entertained admiral Nearchus . in the second account, Diodorus recounts that Alexander was struck with pain after downing a large bowl of unmixed wine .
# multiple accounts of Alexander's death suggest foul play . the strongest argument against the poison theory is the fact that twelve days passed between the start of his illness and his death . if Alexander was poisoned, the plant white hellebore (Veratrum album) may have been used .
# natural-cause theories emphasize that Alexander's health may have been in decline after years of heavy drinking and severe wounds . the anguish that Alexander felt after his death may also have contributed to his declining health .
#
# ### Post-death events
# a seer called Aristander foretold that the land where Alexander was laid to rest "would be happy and unvanquishable forever" perhaps more likely, the successors may have seen possession of the body as a symbol of legitimacy .
# the 2014 discovery of an enormous tomb dating from the time of Alexander the Great has given rise to speculation that it was intended to be the burial place of Alexander . the memorial was found to be dedicated to the dearest friend of Alexander, Hephaestion .
# details on the fate of the tomb in Alexandria are hazy . around AD 200, Emperor Septimius Severus closed the tomb to the public . his son and successor, Caracalla, visited the tomb during his own reign .
# it was originally thought to have been the sarcophagus of Abdalonymus . it was discovered near Sidon and is now in the Istanbul archaeology museum . the bas-reliefs depict Alexander and his companions fighting and hunting .
# demades likened the army, after the death of Alexander, to the blinded Cyclops . "after he had lost his eye went feeling and groping about with his hands before him"
#
# ### Division of the Macedonian Empire
# when reports of Alexander's death reached Greece, they were not immediately believed . a theory is that his successors wilfully or erroneously misheard "tôi Kraterôi"
# arrian and plutarch claimed that Alexander was speechless by this time . Diodorus, Curtius and Justin offered the more plausible story . Alexander passed his signet ring to a bodyguard in front of witnesses .
# perdiccas suggested that Roxane's baby would be king, if male, with himself, Craterus, Leonnatus, and Antipater as guardians . the infantry rejected this arrangement since they had been excluded from the discussion . after the birth of Alexander IV, he and Philip III were appointed joint kings .
# after the assassination of Perdiccas in 321 BC, Macedonian unity collapsed . the Hellenistic world settled into three stable power blocs: Ptolemaic Egypt, Seleucid Syria and East . both Alexander IV and Philip III were murdered in the process .
#
# ### Last plans
# diodorus: Alexander gave detailed written instructions to Craterus before his death . the successors chose not to further implement them, on the grounds they were extravagant . perdiccas had read the notebooks containing Alexander's last plans to troops in Babylon .
# diodorus: Alexander's last plans called for military expansion into the southern and western Mediterranean . it included monumental constructions, intermixing of eastern and western populations, he says .
# many scholars have doubted their historicity . others have suggested that they were invented by later authors . the plan was exaggerated by perdiccas to ensure that troops voted not to carry them out .
#
# ### Character
#
# ### Generalship
# he never lost a battle, despite typically being outnumbered . he used terrain, phalanx and cavalry tactics, bold strategy, and fierce loyalty .
# in his first battle in Asia, Alexander used only a small part of his forces . his phalanx, armed with long pikes, had a considerable advantage over the Persians' scimitars .
# Alexander led the charge in the center, routing the opposing army . darius equipped his chariots with scythes on the wheels to break up the phalanx .
# when faced with unfamiliar opponents, Alexander adapted his forces to his opponents' style . in india, the Macedonians opened their ranks to envelop the elephants .
#
# ### Physical appearance
# historians often give conflicting accounts of Alexander's appearance . ancient authors recorded that he forbade other sculptors from crafting his image . artistic portrayals of Alexander "seek to legitimize him" despite caveats .
# historian Curtius Rufus gives his account of Alexander sitting on the throne of Darius III . he writes that he was a christian and a god . Rufus also wrote the Histories of Alexander the Great:
# one of the royal pages placed a table under Alexander's feet . since his feet did not reach its lowest step, he was placed on the royal throne .
# when darius III's mother first met him, she assumed he was Alexander . hephaestion was the taller and more handsome of the two .
# the Greek biographer Plutarch (c. 45 – c. 120 AD) discusses the accuracy of his depictions:
# aristotle: the outward appearance of Alexander is best represented by statues of him made by Lysippus . in painting him wielder of the thunder-bolt, did not reproduce his complexion, but made it too dark and swarthy . a very pleasant odour exhaled from his skin and that there was a fragrance about his mouth and all his flesh .
# Historians have understood the detail of the pleasant fragrance attributed to Alexander as stemming from a belief in ancient Greece that pleasant scents are characteristic of gods and heroes .
# he has a straight nose, a slightly protruding jaw, full lips and eyes deep set beneath a strongly pronounced forehead . he is also described as having a slight upward tilt of his head to the left.
# the ancient historian Aelian describes Alexander's hair color as "" (xanthn) at the time, hair could mean yellowish, brownish or reddish . it is sometimes claimed that Alexander had one blue and one brown eye .
#
# ### Personality
# his father Philip was probably Alexander's most immediate and influential role model . his mother Olympia encouraged her son to believe it was his destiny to conquer the Persian Empire .
# according to Plutarch, Alexander had a violent temper and rash, impulsive nature . he was also a calmer side—perceptive, logical, and calculating . his intelligent and rational side was amply demonstrated by his ability and success as a general .
# erudite and patronized both arts and sciences . he had little interest in sports or the Olympic games . his unique abilities were demonstrated by inability of any of his generals to unite Macedonia .
# his delusions of grandeur are readily visible in his will and in his desire to conquer the world . the meaning of his epithet has descended into a historical cliché .
# edward mccaffery: Alexander believed himself a deity, or at least sought to deify himself . he says he adopted elements of Persian dress and customs at court, notably proskynesis . this behaviour cost him the sympathies of many of his countrymen, he writes .
#
# ### Personal relationships
# he apparently had two sons, Alexander IV of Macedon by Roxana and Heracles of Macedon from his mistress Barsine .
# hephaestion's death may have contributed to his failing health and detached mental state . he also had a close relationship with his friend and bodyguard .
#
# ### Sexuality
# king's sexuality has been the subject of speculation and controversy in modern times . none of Alexander's contemporaries are known to have explicitly described his relationship with Hephaestion as sexual . some modern historians believe that their sexual contacts may have continued into adulthood .
# green: there is little evidence in ancient sources that Alexander had much sexual interest in women . he says green calculates that he had a higher matrimonial record than his father at the same age . green: two of these pregnancies are of dubious legitimacy .
# according to Diodorus Siculus, Alexander accumulated a harem in the style of Persian kings . Plutarch described how Alexander was infatuated by Roxana while complimenting him on not forcing himself on her .
#
# ### Battle record
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
# : , ; .  () ()( ).
#
# ### Legacy
# some of the cities he founded became major cultural centers, many surviving into the 21st century . his campaigns greatly increased contacts and trade between east and west .
#
# ### Hellenistic kingdoms
# at the time of his death, Alexander's empire covered some 5,200,000 km2 (2,000,000 sq mi) many of these areas remained in Macedonian hands or under Greek influence for the next 200–300 years .
# the eastern borders of Alexander's empire began to collapse even during his lifetime . the power vacuum gave rise to one of the most powerful Indian dynasties in history . Chandragupta Maurya took control of the Punjab, and with that power base proceeded to conquer the Nanda Empire .
#
# ### Founding of cities
# a century or so after Alexander's death, many of the Alexandrias were thriving . the cities' locations reflected trade routes as well as defensive positions .
#
# ### Funding of temples
# the temple was designed by Pytheos, one of the architects of the Mausoleum at Halicarnassus . an inscription from the temple declares: "King Alexander dedicated [this temple] to Athena Polias."
# Libanius wrote that Alexander founded the temple of Zeus Bottiaios in the place where later the city of Antioch was built .
# Suda wrote that Alexander built a big temple to Sarapis . [269] . Suda also wrote that he built the temple to a king of saraphis .
# experts suggest that a Greek temple at Girsu in Iraq, was founded by Alexander . the site "honors Zeus and two divine sons. the sons are Heracles and Alexander"
#
# ### Hellenization
# Hellenization denotes the spread of Greek language, culture, and population into the former Persian empire after Alexander's conquest . this process can be seen in such great Hellenistic cities as Alexandria, Antioch and Seleucia .
# the core of the Hellenistic culture promulgated by the conquests was essentially Athenian . the close association of men from across Greece in Alexander's army led to the emergence of the largely attic-based "koine"
#
# ### Hellenization in South and Central Asia
# some of the most pronounced effects of Hellenization can be seen in the region of the Greco-Bactrian Kingdom (250–125 BC) and the Indo-Greek Kingdom (180 BC – 10 AD) on the Silk Road trade routes, Hellenistic culture hybridized with Iranian and Buddhist cultures .
# some of the first and most influential figurative portrayals of The Buddha appeared at this time . similar practices were also observed amongst the native Indic culture . one Greek king, Menander I, probably became Buddhist .
# a few examples of the Ionic order can be seen as far as Pakistan . the corinthian order is also heavily represented in the art of Gandhara .
#
# ### Influence on Rome
# roman leaders saw Alexander as a role model . the macriani kept images of him on their persons, either on jewellery or embroidered into their clothes . Octavian visited Alexander's tomb in Alexandria and temporarily changed his seal .
# some roman writers used Alexander as a cautionary tale of how autocratic tendencies can be kept in check by republican values . iracundia (anger) and cupiditas gloriae (over-desire for glory)
# "the Caesars" describes a contest between the previous roman emperors . he calls in Alexander the Great as an extra contestant in the presence of the assembled gods.
# Julius Caesar went to serve his quaestorship in hispania after his wife's funeral . while there, he encountered a statue of Alexander the Great, and realised with dissatisfaction he was now at an age when he had the world at his feet .
# he posed as the "new Alexander" since he was his boyhood hero . "the new Alexander" is a fictional character based on a true story .
# the term Phalangarii has two possible meanings, both with military connotations . first refers merely to the Roman battle line and does not specifically mean that the men were armed with pikes . the second bears similarity to the 'Marian Mules' of the late Roman Republic .
# caracalla's mania for Alexander went so far that he persecuted philosophers of the Aristotelian school based on a legend that aristotle had poisoned Alexander . this mania was overshadowed by subsequent events in Alexandria .
# in 39, Caligula ordered a temporary floating bridge to be built using ships as pontoons . the bridge stretched for over two miles from the resort of Baiae to the neighbouring port of Puteoli .
# the diffusion of Greek culture and language served as a "precondition" for the later Roman expansion into these territories, according to errington . he cites a number of factors that contributed to the growth of the Byzantine empire .
#
# ### Letters
# a few official letters addressed to the Greek cities survive in copies inscribed in stone . fictitious letters, some perhaps based on actual letters, made their way into the romance tradition .
#
# ### In legend
# many of the legends about Alexander derby derive from his own lifetime . his court historian Callisthenes portrayed the sea in Cilicia as drawing back from him . onesicritus invented a tryst between Alexander and Thalestris .
# a quantity of the legendary material coalesced into a text known as the Alexander Romance . this text underwent over one hundred recensions, translations, and derivations . it contained many dubious stories and was translated into twenty-five languages .
#
# ### In ancient and modern culture
# the great's accomplishments and legacy have been depicted in many cultures . the Alexander Romance has had a significant impact on portrayals of the great . he has featured in both high and popular culture .
# he is the only ancient hero to appear in the Karagiozis shadow play . a solitary mermaid would grasp a ship's prow and ask the captain, "Is King Alexander alive?" the answer should be "He is alive and well and rules the world!"
# in pre-Islamic Middle Persian (Zoroastrian) literature, Alexander is referred to by the epithet gujastak . in Islamic Persia, under the influence of the Alexander Romance, a more positive portrayal emerges .
# the figure of Dhu al-Qarnayn is believed to be a reference to Alexander the Great . he was a heroic figure who built a wall to defend against the nations of Gog and Magog . in this tradition, he also travelled the known world in search of the water of life .
# he was portrayed as the son of the last pharaoh before the Persian conquest . his defeat of darius was depicted as Egypt's salvation .
# the Book of Daniel describes a mighty Greek king who would conquer the Persian Empire . this is cited as a reason for sparing Jerusalem .
# the name "Sikandar", derived from the Persian name for Alexander, denotes a rising young talent . in medieval India, Turkic and Afghan sovereigns from the Iranian-cultured region of Central Asia brought positive cultural connotations of Alexander .
# in the Greek Anthology, there are poems referring to Alexander . [320][321][220][128]
# the song 'Alexander the Great' by the British heavy metal band Iron Maiden is indicative . some films that have been shot with the theme of Alexander are:
# there are also many references to other movies and TV series . there are a lot of references to the movies and television series i have seen .
# the trilogy "Alexander the Great" by Valerio Massimo Manfredi . "the son of the dream", "the sand of Amon" and "the ends of the world"
# Irish playwright Aubrey Thomas de Vere wrote Alexander the Great, a Dramatic Poem . he is the author of a novel, titled "Alexander the Great," which is based on a poem by the same name .
#
# ### Historiography
# contemporaries who wrote accounts of his life were all lost . later works based on these original sources have survived . the earliest of these is Diodorus Siculus (1st century BC)
#
# ### See also
#
# ### References
#
# ### Notes
#
# ### Citations
#
# ### Sources
#
# ### Primary sources
#
# ### Secondary sources
#
# ### Further reading
#
# ### External links
